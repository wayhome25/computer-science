# %%
import dis # 디스어셈블

# %%
def func(a, b):
    c = a + b
    return c

# %%
dis.dis(func) #바이트 코드
# Out:
#   2           0 LOAD_FAST                0 (a)
#               2 LOAD_FAST                1 (b)
#               4 BINARY_ADD
#               6 STORE_FAST               2 (c)
#
#   3           8 LOAD_FAST                2 (c)
#              10 RETURN_VALUE
