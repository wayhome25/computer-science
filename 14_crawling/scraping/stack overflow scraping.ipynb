# %% [markdown]
# # stack overflow 에서 python 검색 결과 화면을 가져온다

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

page = urlopen("http://stackoverflow.com/questions/tagged/python")
document = page.read()
page.close()

soup = BeautifulSoup(document, 'html5lib')

questions = soup.find(id="questions")
questions_list = questions.find_all("a", class_="question-hyperlink")

for question in questions_list:
    print(question.get_text())
    print('http://stackoverflow.com' + question.get('href'))
# Out:
# Mutually exclusive many-to-many relationship in Django models
# http://stackoverflow.com/questions/43657599/mutually-exclusive-many-to-many-relationship-in-django-models
# How can I get the index of selected item in a treeview?
# http://stackoverflow.com/questions/43657591/how-can-i-get-the-index-of-selected-item-in-a-treeview
# How to install Tkinter module with python 2.7.5 in Redhat linux 7?
# http://stackoverflow.com/questions/43657590/how-to-install-tkinter-module-with-python-2-7-5-in-redhat-linux-7
# Grouping columns in python tabulate alphabetically
# http://stackoverflow.com/questions/43657584/grouping-columns-in-python-tabulate-alphabetically
# function to convert any RGB image into grayscale python
# http://stackoverflow.com/questions/43657547/function-to-convert-any-rgb-image-into-grayscale-python
# Django Memory Issues
# http://stackoverflow.com/questions/43657468/django-memory-issues
# Applying Conditional Formatting over Varying Cell Ranges in Excel (XlsxWriter)
# http://stackoverflow.com/questions/43657398/applying-conditional-formatting-over-varying-cell-ranges-in-excel-xlsxwriter
# Adding missing columns
# http://stackoverflow.com/questions/43657366/adding-missing-columns
# TypeError: a bytes-like object is required, not 'str': Error Getting
# http://stackoverflow.com/questions/43657351/typeerror-a-bytes-like-object-is-required-not-str-error-getting
# Centos 6.6 segmentation fault in Anaconda3 with glibc 2.14
# http://stackoverflow.com/questions/43657242/centos-6-6-segmentation-fault-in-anaconda3-with-glibc-2-14
# How to convert b'\xc8\x00' to float?
# http://stackoverflow.com/questions/43657210/how-to-convert-b-xc8-x00-to-float
# What is the purpose of print()[] syntax in Python? [duplicate]
# http://stackoverflow.com/questions/43657206/what-is-the-purpose-of-print-syntax-in-python
# I need to make a simple file compression system for my GCSE Computer Science
# http://stackoverflow.com/questions/43657161/i-need-to-make-a-simple-file-compression-system-for-my-gcse-computer-science
# Tastypie foreign key dehydrate
# http://stackoverflow.com/questions/43657153/tastypie-foreign-key-dehydrate
# Random AttibuteError on python3
# http://stackoverflow.com/questions/43657122/random-attibuteerror-on-python3
# JSON to Python Dataframe
# http://stackoverflow.com/questions/43656970/json-to-python-dataframe
# Python Find indices of data in array/list, but with constraints
# http://stackoverflow.com/questions/43656966/python-find-indices-of-data-in-array-list-but-with-constraints
# ValueError at /createuser/ invalid literal for int() with base 10: 'satya'
# http://stackoverflow.com/questions/43656883/valueerror-at-createuser-invalid-literal-for-int-with-base-10-satya
# unpacking a split inside a list comprehension [duplicate]
# http://stackoverflow.com/questions/43656861/unpacking-a-split-inside-a-list-comprehension
# Compare Rows in oracle table and update matching ones
# http://stackoverflow.com/questions/43656784/compare-rows-in-oracle-table-and-update-matching-ones
# np.concatenate a list of numpy.ndarray in new dimension?
# http://stackoverflow.com/questions/43656763/np-concatenate-a-list-of-numpy-ndarray-in-new-dimension
# When determining sentiment, I cannot change the colour of the plot on the matplotlib map
# http://stackoverflow.com/questions/43656755/when-determining-sentiment-i-cannot-change-the-colour-of-the-plot-on-the-matplo
# Finding highest value from pandas column containing dictionaries
# http://stackoverflow.com/questions/43656699/finding-highest-value-from-pandas-column-containing-dictionaries
# PyQt: How to add actions to context menu from loop?
# http://stackoverflow.com/questions/43656691/pyqt-how-to-add-actions-to-context-menu-from-loop
# List condition to get true or false in new list
# http://stackoverflow.com/questions/43656672/list-condition-to-get-true-or-false-in-new-list
# Python - row operation against all other records in a file
# http://stackoverflow.com/questions/43656572/python-row-operation-against-all-other-records-in-a-file
# Getting error “index out of range” while removing an element from the list
# http://stackoverflow.com/questions/43656438/getting-error-index-out-of-range-while-removing-an-element-from-the-list
# What GUI add-on can I use in python which I can easily implement on existing code?
# http://stackoverflow.com/questions/43656425/what-gui-add-on-can-i-use-in-python-which-i-can-easily-implement-on-existing-cod
# Don't understand why this TypeError: must be str, not float exception occurs
# http://stackoverflow.com/questions/43656420/dont-understand-why-this-typeerror-must-be-str-not-float-exception-occurs
# Pick rows above a row that meets a condition in Pandas
# http://stackoverflow.com/questions/43656348/pick-rows-above-a-row-that-meets-a-condition-in-pandas
# Comparing a list of tuples
# http://stackoverflow.com/questions/43656308/comparing-a-list-of-tuples
# how to install tornado for python of different version
# http://stackoverflow.com/questions/43656303/how-to-install-tornado-for-python-of-different-version
# How to exlcude grey code from the file with all the existing patterns
# http://stackoverflow.com/questions/43656223/how-to-exlcude-grey-code-from-the-file-with-all-the-existing-patterns
# catching exceptions in python3 multiprocessing
# http://stackoverflow.com/questions/43656214/catching-exceptions-in-python3-multiprocessing
# Python- using odeint with two equations
# http://stackoverflow.com/questions/43656128/python-using-odeint-with-two-equations
# screen.get_at(): colour of image changes whilst running code pygame
# http://stackoverflow.com/questions/43656103/screen-get-at-colour-of-image-changes-whilst-running-code-pygame
# How would my database relationship look like. Flask sqlalchemy
# http://stackoverflow.com/questions/43656094/how-would-my-database-relationship-look-like-flask-sqlalchemy
# Problems importing cx_oracle
# http://stackoverflow.com/questions/43656091/problems-importing-cx-oracle
# Word sense disambiguation with WordNet. How to select the words related to the same meaning?
# http://stackoverflow.com/questions/43656078/word-sense-disambiguation-with-wordnet-how-to-select-the-words-related-to-the-s
# Flask+Apache2 Relative path throwing file not found error [duplicate]
# http://stackoverflow.com/questions/43656067/flaskapache2-relative-path-throwing-file-not-found-error
# How to import from sibling module in a package?
# http://stackoverflow.com/questions/43656066/how-to-import-from-sibling-module-in-a-package
# String index out of range - Python
# http://stackoverflow.com/questions/43656058/string-index-out-of-range-python
# How do I check if there are any duplicates in a row in a matrix?
# http://stackoverflow.com/questions/43655998/how-do-i-check-if-there-are-any-duplicates-in-a-row-in-a-matrix
# Accessing Tk Inter widgets from one class and displaying on another class
# http://stackoverflow.com/questions/43655951/accessing-tk-inter-widgets-from-one-class-and-displaying-on-another-class
# Python lxml xpath returns no output
# http://stackoverflow.com/questions/43655937/python-lxml-xpath-returns-no-output
# Extracting values from .dat file in python
# http://stackoverflow.com/questions/43655892/extracting-values-from-dat-file-in-python
# Using a value from one class in another in python tkinter [duplicate]
# http://stackoverflow.com/questions/43655874/using-a-value-from-one-class-in-another-in-python-tkinter
# Python, replace digits with alphabet in string
# http://stackoverflow.com/questions/43655864/python-replace-digits-with-alphabet-in-string
# Python-Regular Expression: Matching single or double quoted string [duplicate]
# http://stackoverflow.com/questions/43655846/python-regular-expression-matching-single-or-double-quoted-string
# Reading raw (binary?) Tiedot (NOSQL / JSON) data from Onionscan using Python
# http://stackoverflow.com/questions/43655788/reading-raw-binary-tiedot-nosql-json-data-from-onionscan-using-python
