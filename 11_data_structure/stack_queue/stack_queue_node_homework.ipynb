# %%
class Node:
    def __init__(self, data):
        self.data = data 
        self.next = None 

class Stack:
    def __init__(self):
        self.head = None
        
    def push(self, data):
        new_data = Node(data)
        self.head = new_data
        
#    나머지 직접 만들어보기

# %%
class Node:
    def __init__(self, data):
        self.data = data 
        self.next = None 

class Queue:
